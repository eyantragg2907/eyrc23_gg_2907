# %%
# my own convolutional network implementation

# %%
import torch
from torch import nn
from torch.utils.data import DataLoader

# Import torchvision 
import torchvision
from torchvision import datasets
from torchvision.transforms import ToTensor

# Import matplotlib for visualization
import matplotlib.pyplot as plt

# %%
device = "mps" if torch.backends.mps.is_available() else "cpu"
device
# Out:
# 'mps'

# %%
class_names = ["combat", "building", "fire", "rehab", "military"]

# %%
class MyNetwork(torch.nn.Module):
	def __init__(self, numChannels, classes):
		super(MyNetwork, self).__init__()
        
		# initialize first set of CONV => RELU => POOL layers
		self.conv1 = torch.nn.Conv2d(in_channels=numChannels, out_channels=20,
			kernel_size=(5, 5))
		self.relu1 = torch.nn.ReLU()
		self.maxpool1 = torch.nn.MaxPool2d(kernel_size=(2, 2), stride=(2, 2))
		# initialize second set of CONV => RELU => POOL layers
		self.conv2 = torch.nn.Conv2d(in_channels=20, out_channels=50,
			kernel_size=(5, 5))
		self.relu2 = torch.nn.ReLU()
		self.maxpool2 = torch.nn.MaxPool2d(kernel_size=(2, 2), stride=(2, 2))
		# initialize first (and only) set of FC => RELU layers
		self.flatten = torch.nn.Flatten()
		self.fc1 = torch.nn.Linear(in_features=186050, out_features=500)
		self.relu3 = torch.nn.ReLU()
		# initialize our softmax classifier
		self.fc2 = torch.nn.Linear(in_features=500, out_features=classes)
		self.logSoftmax = torch.nn.LogSoftmax(dim=1)

	def forward(self, x):
		# pass the input through our first set of CONV => RELU =>
		# POOL layers
		x = self.conv1(x)
		x = self.relu1(x)
		x = self.maxpool1(x)
		# pass the output from the previous layer through the second
		# set of CONV => RELU => POOL layers
		x = self.conv2(x)
		x = self.relu2(x)
		x = self.maxpool2(x)
		# flatten the output from the previous layer and pass it
		# through our only set of FC => RELU layers
		x = self.flatten(x)
		x = self.fc1(x)
		x = self.relu3(x)
		# pass the output to our softmax classifier to get our output
		# predictions
		x = self.fc2(x)
		output = self.logSoftmax(x)
		# return the output predictions
		return output

# %%
# load the image data from "train" folder
train_data = datasets.ImageFolder(root="train", transform=torchvision.transforms.Compose([torchvision.transforms.Resize((256,256)), ToTensor()]))

# %%
test_data = datasets.ImageFolder(root="test", transform=torchvision.transforms.Compose([torchvision.transforms.Resize((256,256)), ToTensor()]))

# %%
BATCH_SIZE = 32

# %%
train_dataloader = DataLoader(train_data, # dataset to turn into iterable
    batch_size=BATCH_SIZE, # how many samples per batch? 
    shuffle=True # shuffle data every epoch?
)

test_dataloader = DataLoader(test_data, # dataset to turn into iterable
    batch_size=BATCH_SIZE, # how many samples per batch? 
    shuffle=True # shuffle data every epoch?
)

# %%
# train_features_batch, train_labels_batch = next(iter(train_dataloader))
# train_features_batch.shape, train_labels_batch.shape

# %%
# torch.manual_seed(42)
# random_idx = torch.randint(0, len(train_features_batch), size=[1]).item()
# img, label = train_features_batch[random_idx], train_labels_batch[random_idx]

# plt.imshow(img.T)
# plt.title(class_names[label])
# plt.axis("off")
# print(f"Image size: {img.shape}")
# print(f"Label: {label}, label size: {label.shape}")
# plt.show()

# %%
torch.manual_seed(42)

model = MyNetwork(numChannels=3, classes=5).to(device)

loss_fn = nn.CrossEntropyLoss() # this is also called "criterion"/"cost function" in some places
optimizer = torch.optim.SGD(params=model.parameters(), lr=0.01)

# %%
# next(model.parameters()).device
# Out:
# device(type='mps', index=0)

# %%
from helper_functions import accuracy_fn
from timeit import default_timer as timer 
from tqdm.auto import tqdm

# %%
def print_train_time(start: float, end: float, device: torch.device = None):
    total_time = end - start
    print(f"Train time on {device}: {total_time:.3f} seconds")
    return total_time

# %%
# Set the seed and start the timer
torch.manual_seed(42)
train_time_start_on_cpu = timer()

# Set the number of epochs (we'll keep this small for faster training times)
epochs = 3

# Create training and testing loop
for epoch in tqdm(range(epochs)):
    print(f"Epoch: {epoch}\n-------")
    ### Training
    train_loss, train_acc = 0, 0
    # Add a loop to loop through training batches
    for batch, (X, y) in enumerate(train_dataloader):

        X, y = X.to(device), y.to(device)

        # model.train() 
        # 1. Forward pass
        y_pred = model(X)

        # 2. Calculate loss (per batch)
        loss = loss_fn(y_pred, y)
        train_loss += loss # accumulatively add up the loss per epoch 

        # 3. Optimizer zero grad
        optimizer.zero_grad()

        # 4. Loss backward
        loss.backward()

        # 5. Optimizer step
        optimizer.step()

        train_acc += accuracy_fn(y_true=y, y_pred=y_pred.argmax(dim=1))
        
        # Print out how many samples have been seen
        # if batch % 160 == 0:
        print(f"Looked at {batch * len(X)}/{len(train_dataloader.dataset)} samples")

    # Divide total train loss by length of train dataloader (average loss per batch per epoch)
    train_loss /= len(train_dataloader)
    train_acc /= len(train_dataloader)
    
    ### Testing
    # Setup variables for accumulatively adding up loss and accuracy 
    test_loss, test_acc = 0, 0 
    model.eval()
    with torch.inference_mode():
        for X, y in test_dataloader:

            X, y = X.to(device), y.to(device)
            
            # 1. Forward pass
            test_pred = model(X)
           
            # 2. Calculate loss (accumatively)
            test_loss += loss_fn(test_pred, y) # accumulatively add up the loss per epoch

            # 3. Calculate accuracy (preds need to be same as y_true)
            test_acc += accuracy_fn(y_true=y, y_pred=test_pred.argmax(dim=1))
        
            # Calculations on test metrics need to happen inside torch.inference_mode()
            # Divide total test loss by length of test dataloader (per batch)
            test_loss /= len(test_dataloader)

            # Divide total accuracy by length of test dataloader (per batch)
            test_acc /= len(test_dataloader)

    ## Print out what's happening
    print(f"\nTrain loss: {train_loss:.5f}, Train acc: {train_acc:.2f}% | Test loss: {test_loss:.5f}, Test acc: {test_acc:.2f}%\n")

# Calculate training time      
train_time_end_on_cpu = timer()
total_train_time_model_0 = print_train_time(start=train_time_start_on_cpu, 
                                           end=train_time_end_on_cpu,
                                           device=str(next(model.parameters()).device))
# Out:
#   0%|          | 0/3 [00:00<?, ?it/s]
# Epoch: 0
# -------
# Looked at 0/9112 samples
# Looked at 32/9112 samples
# Looked at 64/9112 samples
# Looked at 96/9112 samples
# Looked at 128/9112 samples
# Looked at 160/9112 samples
# Looked at 192/9112 samples
# Looked at 224/9112 samples
# Looked at 256/9112 samples
# Looked at 288/9112 samples
# Looked at 320/9112 samples
# Looked at 352/9112 samples
# Looked at 384/9112 samples
# Looked at 416/9112 samples
# Looked at 448/9112 samples
# Looked at 480/9112 samples
# Looked at 512/9112 samples
# Looked at 544/9112 samples
# Looked at 576/9112 samples
# Looked at 608/9112 samples
# Looked at 640/9112 samples
# Looked at 672/9112 samples
# Looked at 704/9112 samples
# Looked at 736/9112 samples
# Looked at 768/9112 samples
# Looked at 800/9112 samples
# Looked at 832/9112 samples
# Looked at 864/9112 samples
# Looked at 896/9112 samples
# Looked at 928/9112 samples
# Looked at 960/9112 samples
# Looked at 992/9112 samples
# Looked at 1024/9112 samples
# Looked at 1056/9112 samples
# Looked at 1088/9112 samples
# Looked at 1120/9112 samples
# Looked at 1152/9112 samples
# Looked at 1184/9112 samples
# Looked at 1216/9112 samples
# Looked at 1248/9112 samples
# Looked at 1280/9112 samples
# Looked at 1312/9112 samples
# Looked at 1344/9112 samples
# Looked at 1376/9112 samples
# Looked at 1408/9112 samples
# Looked at 1440/9112 samples
# Looked at 1472/9112 samples
# Looked at 1504/9112 samples
# Looked at 1536/9112 samples
# Looked at 1568/9112 samples
# Looked at 1600/9112 samples
# Looked at 1632/9112 samples
# Looked at 1664/9112 samples
# Looked at 1696/9112 samples
# Looked at 1728/9112 samples
# Looked at 1760/9112 samples
# Looked at 1792/9112 samples
# Looked at 1824/9112 samples
# Looked at 1856/9112 samples
# Looked at 1888/9112 samples
# Looked at 1920/9112 samples
# Looked at 1952/9112 samples
# Looked at 1984/9112 samples
# Looked at 2016/9112 samples
# Looked at 2048/9112 samples
# Looked at 2080/9112 samples
# Looked at 2112/9112 samples
# Looked at 2144/9112 samples
# Looked at 2176/9112 samples
# Looked at 2208/9112 samples
# Looked at 2240/9112 samples
# Looked at 2272/9112 samples
# Looked at 2304/9112 samples
# Looked at 2336/9112 samples
# Looked at 2368/9112 samples
# Looked at 2400/9112 samples
# Looked at 2432/9112 samples
# Looked at 2464/9112 samples
# Looked at 2496/9112 samples
# Looked at 2528/9112 samples
# Looked at 2560/9112 samples
# Looked at 2592/9112 samples
# Looked at 2624/9112 samples
# Looked at 2656/9112 samples
# Looked at 2688/9112 samples
# Looked at 2720/9112 samples
# Looked at 2752/9112 samples
# Looked at 2784/9112 samples
# Looked at 2816/9112 samples
# Looked at 2848/9112 samples
# Looked at 2880/9112 samples
# Looked at 2912/9112 samples
# Looked at 2944/9112 samples
# Looked at 2976/9112 samples
# Looked at 3008/9112 samples
# Looked at 3040/9112 samples
# Looked at 3072/9112 samples
# Looked at 3104/9112 samples
# Looked at 3136/9112 samples
# Looked at 3168/9112 samples
# Looked at 3200/9112 samples
# Looked at 3232/9112 samples
# Looked at 3264/9112 samples
# Looked at 3296/9112 samples
# Looked at 3328/9112 samples
# Looked at 3360/9112 samples
# Looked at 3392/9112 samples
# Looked at 3424/9112 samples
# Looked at 3456/9112 samples
# Looked at 3488/9112 samples
# Looked at 3520/9112 samples
# Looked at 3552/9112 samples
# Looked at 3584/9112 samples
# Looked at 3616/9112 samples
# Looked at 3648/9112 samples
# Looked at 3680/9112 samples
# Looked at 3712/9112 samples
# Looked at 3744/9112 samples
# Looked at 3776/9112 samples
# Looked at 3808/9112 samples
# Looked at 3840/9112 samples
# Looked at 3872/9112 samples
# Looked at 3904/9112 samples
# Looked at 3936/9112 samples
# Looked at 3968/9112 samples
# Looked at 4000/9112 samples
# Looked at 4032/9112 samples
# Looked at 4064/9112 samples
# Looked at 4096/9112 samples
# Looked at 4128/9112 samples
# Looked at 4160/9112 samples
# Looked at 4192/9112 samples
# Looked at 4224/9112 samples
# Looked at 4256/9112 samples
# Looked at 4288/9112 samples
# Looked at 4320/9112 samples
# Looked at 4352/9112 samples
# Looked at 4384/9112 samples
# Looked at 4416/9112 samples
# Looked at 4448/9112 samples
# Looked at 4480/9112 samples
# Looked at 4512/9112 samples
# Looked at 4544/9112 samples
# Looked at 4576/9112 samples
# Looked at 4608/9112 samples
# Looked at 4640/9112 samples
# Looked at 4672/9112 samples
# Looked at 4704/9112 samples
# Looked at 4736/9112 samples
# Looked at 4768/9112 samples
# Looked at 4800/9112 samples
# Looked at 4832/9112 samples
# Looked at 4864/9112 samples
# Looked at 4896/9112 samples
# Looked at 4928/9112 samples
# Looked at 4960/9112 samples
# Looked at 4992/9112 samples
# Looked at 5024/9112 samples
# Looked at 5056/9112 samples
# Looked at 5088/9112 samples
# Looked at 5120/9112 samples
# Looked at 5152/9112 samples
# Looked at 5184/9112 samples
# Looked at 5216/9112 samples
# Looked at 5248/9112 samples
# Looked at 5280/9112 samples
# Looked at 5312/9112 samples
# Looked at 5344/9112 samples
# Looked at 5376/9112 samples
# Looked at 5408/9112 samples
# Looked at 5440/9112 samples
# Looked at 5472/9112 samples
# Looked at 5504/9112 samples
# Looked at 5536/9112 samples
# Looked at 5568/9112 samples
# Looked at 5600/9112 samples
# Looked at 5632/9112 samples
# Looked at 5664/9112 samples
# Looked at 5696/9112 samples
# Looked at 5728/9112 samples
# Looked at 5760/9112 samples
# Looked at 5792/9112 samples
# Looked at 5824/9112 samples
# Looked at 5856/9112 samples
# Looked at 5888/9112 samples
# Looked at 5920/9112 samples
# Looked at 5952/9112 samples
# Looked at 5984/9112 samples
# Looked at 6016/9112 samples
# Looked at 6048/9112 samples
# Looked at 6080/9112 samples
# Looked at 6112/9112 samples
# Looked at 6144/9112 samples
# Looked at 6176/9112 samples
# Looked at 6208/9112 samples
# Looked at 6240/9112 samples
# Looked at 6272/9112 samples
# Looked at 6304/9112 samples
# Looked at 6336/9112 samples
# Looked at 6368/9112 samples
# Looked at 6400/9112 samples
# Looked at 6432/9112 samples
# Looked at 6464/9112 samples
# Looked at 6496/9112 samples
# Looked at 6528/9112 samples
# Looked at 6560/9112 samples
# Looked at 6592/9112 samples
# Looked at 6624/9112 samples
# Looked at 6656/9112 samples
# Looked at 6688/9112 samples
# Looked at 6720/9112 samples
# Looked at 6752/9112 samples
# Looked at 6784/9112 samples
# Looked at 6816/9112 samples
# Looked at 6848/9112 samples
# Looked at 6880/9112 samples
# Looked at 6912/9112 samples
# Looked at 6944/9112 samples
# Looked at 6976/9112 samples
# Looked at 7008/9112 samples
# Looked at 7040/9112 samples
# Looked at 7072/9112 samples
# Looked at 7104/9112 samples
# Looked at 7136/9112 samples
# Looked at 7168/9112 samples
# Looked at 7200/9112 samples
# Looked at 7232/9112 samples
# Looked at 7264/9112 samples
# Looked at 7296/9112 samples
# Looked at 7328/9112 samples
# Looked at 7360/9112 samples
# Looked at 7392/9112 samples
# Looked at 7424/9112 samples
# Looked at 7456/9112 samples
# Looked at 7488/9112 samples
# Looked at 7520/9112 samples
# Looked at 7552/9112 samples
# Looked at 7584/9112 samples
# Looked at 7616/9112 samples
# Looked at 7648/9112 samples
# Looked at 7680/9112 samples
# Looked at 7712/9112 samples
# Looked at 7744/9112 samples
# Looked at 7776/9112 samples
# Looked at 7808/9112 samples
# Looked at 7840/9112 samples
# Looked at 7872/9112 samples
# Looked at 7904/9112 samples
# Looked at 7936/9112 samples
# Looked at 7968/9112 samples
# Looked at 8000/9112 samples
# Looked at 8032/9112 samples
# Looked at 8064/9112 samples
# Looked at 8096/9112 samples
# Looked at 8128/9112 samples
# Looked at 8160/9112 samples
# Looked at 8192/9112 samples
# Looked at 8224/9112 samples
# Looked at 8256/9112 samples
# Looked at 8288/9112 samples
# Looked at 8320/9112 samples
# Looked at 8352/9112 samples
# Looked at 8384/9112 samples
# Looked at 8416/9112 samples
# Looked at 8448/9112 samples
# Looked at 8480/9112 samples
# Looked at 8512/9112 samples
# Looked at 8544/9112 samples
# Looked at 8576/9112 samples
# Looked at 8608/9112 samples
# Looked at 8640/9112 samples
# Looked at 8672/9112 samples
# Looked at 8704/9112 samples
# Looked at 8736/9112 samples
# Looked at 8768/9112 samples
# Looked at 8800/9112 samples
# Looked at 8832/9112 samples
# Looked at 8864/9112 samples
# Looked at 8896/9112 samples
# Looked at 8928/9112 samples
# Looked at 8960/9112 samples
# Looked at 8992/9112 samples
# Looked at 9024/9112 samples
# Looked at 9056/9112 samples
# Looked at 6816/9112 samples
#
# Train loss: 0.10468, Train acc: 96.90% | Test loss: 1.22927, Test acc: 60.00%
#
# Epoch: 1
# -------
# Looked at 0/9112 samples
# Looked at 32/9112 samples
# Looked at 64/9112 samples
# Looked at 96/9112 samples
# Looked at 128/9112 samples
# Looked at 160/9112 samples
# Looked at 192/9112 samples
# Looked at 224/9112 samples
# Looked at 256/9112 samples
# Looked at 288/9112 samples
# Looked at 320/9112 samples
# Looked at 352/9112 samples
# Looked at 384/9112 samples
# Looked at 416/9112 samples
# Looked at 448/9112 samples
# Looked at 480/9112 samples
# Looked at 512/9112 samples
# Looked at 544/9112 samples
# Looked at 576/9112 samples
# Looked at 608/9112 samples
# Looked at 640/9112 samples
# Looked at 672/9112 samples
# Looked at 704/9112 samples
# Looked at 736/9112 samples
# Looked at 768/9112 samples
# Looked at 800/9112 samples
# Looked at 832/9112 samples
# Looked at 864/9112 samples
# Looked at 896/9112 samples
# Looked at 928/9112 samples
# Looked at 960/9112 samples
# Looked at 992/9112 samples
# Looked at 1024/9112 samples
# Looked at 1056/9112 samples
# Looked at 1088/9112 samples
# Looked at 1120/9112 samples
# Looked at 1152/9112 samples
# Looked at 1184/9112 samples
# Looked at 1216/9112 samples
# Looked at 1248/9112 samples
# Looked at 1280/9112 samples
# Looked at 1312/9112 samples
# Looked at 1344/9112 samples
# Looked at 1376/9112 samples
# Looked at 1408/9112 samples
# Looked at 1440/9112 samples
# Looked at 1472/9112 samples
# Looked at 1504/9112 samples
# Looked at 1536/9112 samples
# Looked at 1568/9112 samples
# Looked at 1600/9112 samples
# Looked at 1632/9112 samples
# Looked at 1664/9112 samples
# Looked at 1696/9112 samples
# Looked at 1728/9112 samples
# Looked at 1760/9112 samples
# Looked at 1792/9112 samples
# Looked at 1824/9112 samples
# Looked at 1856/9112 samples
# Looked at 1888/9112 samples
# Looked at 1920/9112 samples
# Looked at 1952/9112 samples
# Looked at 1984/9112 samples
# Looked at 2016/9112 samples
# Looked at 2048/9112 samples
# Looked at 2080/9112 samples
# Looked at 2112/9112 samples
# Looked at 2144/9112 samples
# Looked at 2176/9112 samples
# Looked at 2208/9112 samples
# Looked at 2240/9112 samples
# Looked at 2272/9112 samples
# Looked at 2304/9112 samples
# Looked at 2336/9112 samples
# Looked at 2368/9112 samples
# Looked at 2400/9112 samples
# Looked at 2432/9112 samples
# Looked at 2464/9112 samples
# Looked at 2496/9112 samples
# Looked at 2528/9112 samples
# Looked at 2560/9112 samples
# Looked at 2592/9112 samples
# Looked at 2624/9112 samples
# Looked at 2656/9112 samples
# Looked at 2688/9112 samples
# Looked at 2720/9112 samples
# Looked at 2752/9112 samples
# Looked at 2784/9112 samples
# Looked at 2816/9112 samples
# Looked at 2848/9112 samples
# Looked at 2880/9112 samples
# Looked at 2912/9112 samples
# Looked at 2944/9112 samples
# Looked at 2976/9112 samples
# Looked at 3008/9112 samples
# Looked at 3040/9112 samples
# Looked at 3072/9112 samples
# Looked at 3104/9112 samples
# Looked at 3136/9112 samples
# Looked at 3168/9112 samples
# Looked at 3200/9112 samples
# Looked at 3232/9112 samples
# Looked at 3264/9112 samples
# Looked at 3296/9112 samples
# Looked at 3328/9112 samples
# Looked at 3360/9112 samples
# Looked at 3392/9112 samples
# Looked at 3424/9112 samples
# Looked at 3456/9112 samples
# Looked at 3488/9112 samples
# Looked at 3520/9112 samples
# Looked at 3552/9112 samples
# Looked at 3584/9112 samples
# Looked at 3616/9112 samples
# Looked at 3648/9112 samples
# Looked at 3680/9112 samples
# Looked at 3712/9112 samples
# Looked at 3744/9112 samples
# Looked at 3776/9112 samples
# Looked at 3808/9112 samples
# Looked at 3840/9112 samples
# Looked at 3872/9112 samples
# Looked at 3904/9112 samples
# Looked at 3936/9112 samples
# Looked at 3968/9112 samples
# Looked at 4000/9112 samples
# Looked at 4032/9112 samples
# Looked at 4064/9112 samples
# Looked at 4096/9112 samples
# Looked at 4128/9112 samples
# Looked at 4160/9112 samples
# Looked at 4192/9112 samples
# Looked at 4224/9112 samples
# Looked at 4256/9112 samples
# Looked at 4288/9112 samples
# Looked at 4320/9112 samples
# Looked at 4352/9112 samples
# Looked at 4384/9112 samples
# Looked at 4416/9112 samples
# Looked at 4448/9112 samples
# Looked at 4480/9112 samples
# Looked at 4512/9112 samples
# Looked at 4544/9112 samples
# Looked at 4576/9112 samples
# Looked at 4608/9112 samples
# Looked at 4640/9112 samples
# Looked at 4672/9112 samples
# Looked at 4704/9112 samples
# Looked at 4736/9112 samples
# Looked at 4768/9112 samples
# Looked at 4800/9112 samples
# Looked at 4832/9112 samples
# Looked at 4864/9112 samples
# Looked at 4896/9112 samples
# Looked at 4928/9112 samples
# Looked at 4960/9112 samples
# Looked at 4992/9112 samples
# Looked at 5024/9112 samples
# Looked at 5056/9112 samples
# Looked at 5088/9112 samples
# Looked at 5120/9112 samples
# Looked at 5152/9112 samples
# Looked at 5184/9112 samples
# Looked at 5216/9112 samples
# Looked at 5248/9112 samples
# Looked at 5280/9112 samples
# Looked at 5312/9112 samples
# Looked at 5344/9112 samples
# Looked at 5376/9112 samples
# Looked at 5408/9112 samples
# Looked at 5440/9112 samples
# Looked at 5472/9112 samples
# Looked at 5504/9112 samples
# Looked at 5536/9112 samples
# Looked at 5568/9112 samples
# Looked at 5600/9112 samples
# Looked at 5632/9112 samples
# Looked at 5664/9112 samples
# Looked at 5696/9112 samples
# Looked at 5728/9112 samples
# Looked at 5760/9112 samples
# Looked at 5792/9112 samples
# Looked at 5824/9112 samples
# Looked at 5856/9112 samples
# Looked at 5888/9112 samples
# Looked at 5920/9112 samples
# Looked at 5952/9112 samples
# Looked at 5984/9112 samples
# Looked at 6016/9112 samples
# Looked at 6048/9112 samples
# Looked at 6080/9112 samples
# Looked at 6112/9112 samples
# Looked at 6144/9112 samples
# Looked at 6176/9112 samples
# Looked at 6208/9112 samples
# Looked at 6240/9112 samples
# Looked at 6272/9112 samples
# Looked at 6304/9112 samples
# Looked at 6336/9112 samples
# Looked at 6368/9112 samples
# Looked at 6400/9112 samples
# Looked at 6432/9112 samples
# Looked at 6464/9112 samples
# Looked at 6496/9112 samples
# Looked at 6528/9112 samples
# Looked at 6560/9112 samples
# Looked at 6592/9112 samples
# Looked at 6624/9112 samples
# Looked at 6656/9112 samples
# Looked at 6688/9112 samples
# Looked at 6720/9112 samples
# Looked at 6752/9112 samples
# Looked at 6784/9112 samples
# Looked at 6816/9112 samples
# Looked at 6848/9112 samples
# Looked at 6880/9112 samples
# Looked at 6912/9112 samples
# Looked at 6944/9112 samples
# Looked at 6976/9112 samples
# Looked at 7008/9112 samples
# Looked at 7040/9112 samples
# Looked at 7072/9112 samples
# Looked at 7104/9112 samples
# Looked at 7136/9112 samples
# Looked at 7168/9112 samples
# Looked at 7200/9112 samples
# Looked at 7232/9112 samples
# Looked at 7264/9112 samples
# Looked at 7296/9112 samples
# Looked at 7328/9112 samples
# Looked at 7360/9112 samples
# Looked at 7392/9112 samples
# Looked at 7424/9112 samples
# Looked at 7456/9112 samples
# Looked at 7488/9112 samples
# Looked at 7520/9112 samples
# Looked at 7552/9112 samples
# Looked at 7584/9112 samples
# Looked at 7616/9112 samples
# Looked at 7648/9112 samples
# Looked at 7680/9112 samples
# Looked at 7712/9112 samples
# Looked at 7744/9112 samples
# Looked at 7776/9112 samples
# Looked at 7808/9112 samples
# Looked at 7840/9112 samples
# Looked at 7872/9112 samples
# Looked at 7904/9112 samples
# Looked at 7936/9112 samples
# Looked at 7968/9112 samples
# Looked at 8000/9112 samples
# Looked at 8032/9112 samples
# Looked at 8064/9112 samples
# Looked at 8096/9112 samples
# Looked at 8128/9112 samples
# Looked at 8160/9112 samples
# Looked at 8192/9112 samples
# Looked at 8224/9112 samples
# Looked at 8256/9112 samples
# Looked at 8288/9112 samples
# Looked at 8320/9112 samples
# Looked at 8352/9112 samples
# Looked at 8384/9112 samples
# Looked at 8416/9112 samples
# Looked at 8448/9112 samples
# Looked at 8480/9112 samples
# Looked at 8512/9112 samples
# Looked at 8544/9112 samples
# Looked at 8576/9112 samples
# Looked at 8608/9112 samples
# Looked at 8640/9112 samples
# Looked at 8672/9112 samples
# Looked at 8704/9112 samples
# Looked at 8736/9112 samples
# Looked at 8768/9112 samples
# Looked at 8800/9112 samples
# Looked at 8832/9112 samples
# Looked at 8864/9112 samples
# Looked at 8896/9112 samples
# Looked at 8928/9112 samples
# Looked at 8960/9112 samples
# Looked at 8992/9112 samples
# Looked at 9024/9112 samples
# Looked at 9056/9112 samples
# Looked at 6816/9112 samples
#
# Train loss: 0.10218, Train acc: 96.84% | Test loss: 1.43643, Test acc: 60.00%
#
# Epoch: 2
# -------
# Looked at 0/9112 samples
# Looked at 32/9112 samples
# Looked at 64/9112 samples
# Looked at 96/9112 samples
# Looked at 128/9112 samples
# Looked at 160/9112 samples
# Looked at 192/9112 samples
# Looked at 224/9112 samples
# Looked at 256/9112 samples
# Looked at 288/9112 samples
# Looked at 320/9112 samples
# Looked at 352/9112 samples
# Looked at 384/9112 samples
# Looked at 416/9112 samples
# Looked at 448/9112 samples
# Looked at 480/9112 samples
# Looked at 512/9112 samples
# Looked at 544/9112 samples
# Looked at 576/9112 samples
# Looked at 608/9112 samples
# Looked at 640/9112 samples
# Looked at 672/9112 samples
# Looked at 704/9112 samples
# Looked at 736/9112 samples
# Looked at 768/9112 samples
# Looked at 800/9112 samples
# Looked at 832/9112 samples
# Looked at 864/9112 samples
# Looked at 896/9112 samples
# Looked at 928/9112 samples
# Looked at 960/9112 samples
# Looked at 992/9112 samples
# Looked at 1024/9112 samples
# Looked at 1056/9112 samples
# Looked at 1088/9112 samples
# Looked at 1120/9112 samples
# Looked at 1152/9112 samples
# Looked at 1184/9112 samples
# Looked at 1216/9112 samples
# Looked at 1248/9112 samples
# Looked at 1280/9112 samples
# Looked at 1312/9112 samples
# Looked at 1344/9112 samples
# Looked at 1376/9112 samples
# Looked at 1408/9112 samples
# Looked at 1440/9112 samples
# Looked at 1472/9112 samples
# Looked at 1504/9112 samples
# Looked at 1536/9112 samples
# Looked at 1568/9112 samples
# Looked at 1600/9112 samples
# Looked at 1632/9112 samples
# Looked at 1664/9112 samples
# Looked at 1696/9112 samples
# Looked at 1728/9112 samples
# Looked at 1760/9112 samples
# Looked at 1792/9112 samples
# Looked at 1824/9112 samples
# Looked at 1856/9112 samples
# Looked at 1888/9112 samples
# Looked at 1920/9112 samples
# Looked at 1952/9112 samples
# Looked at 1984/9112 samples
# Looked at 2016/9112 samples
# Looked at 2048/9112 samples
# Looked at 2080/9112 samples
# Looked at 2112/9112 samples
# Looked at 2144/9112 samples
# Looked at 2176/9112 samples
# Looked at 2208/9112 samples
# Looked at 2240/9112 samples
# Looked at 2272/9112 samples
# Looked at 2304/9112 samples
# Looked at 2336/9112 samples
# Looked at 2368/9112 samples
# Looked at 2400/9112 samples
# Looked at 2432/9112 samples
# Looked at 2464/9112 samples
# Looked at 2496/9112 samples
# Looked at 2528/9112 samples
# Looked at 2560/9112 samples
# Looked at 2592/9112 samples
# Looked at 2624/9112 samples
# Looked at 2656/9112 samples
# Looked at 2688/9112 samples
# Looked at 2720/9112 samples
# Looked at 2752/9112 samples
# Looked at 2784/9112 samples
# Looked at 2816/9112 samples
# Looked at 2848/9112 samples
# Looked at 2880/9112 samples
# Looked at 2912/9112 samples
# Looked at 2944/9112 samples
# Looked at 2976/9112 samples
# Looked at 3008/9112 samples
# Looked at 3040/9112 samples
# Looked at 3072/9112 samples
# Looked at 3104/9112 samples
# Looked at 3136/9112 samples
# Looked at 3168/9112 samples
# Looked at 3200/9112 samples
# Looked at 3232/9112 samples
# Looked at 3264/9112 samples
# Looked at 3296/9112 samples
# Looked at 3328/9112 samples
# Looked at 3360/9112 samples
# Looked at 3392/9112 samples
# Looked at 3424/9112 samples
# Looked at 3456/9112 samples
# Looked at 3488/9112 samples
# Looked at 3520/9112 samples
# Looked at 3552/9112 samples
# Looked at 3584/9112 samples
# Looked at 3616/9112 samples
# Looked at 3648/9112 samples
# Looked at 3680/9112 samples
# Looked at 3712/9112 samples
# Looked at 3744/9112 samples
# Looked at 3776/9112 samples
# Looked at 3808/9112 samples
# Looked at 3840/9112 samples
# Looked at 3872/9112 samples
# Looked at 3904/9112 samples
# Looked at 3936/9112 samples
# Looked at 3968/9112 samples
# Looked at 4000/9112 samples
# Looked at 4032/9112 samples
# Looked at 4064/9112 samples
# Looked at 4096/9112 samples
# Looked at 4128/9112 samples
# Looked at 4160/9112 samples
# Looked at 4192/9112 samples
# Looked at 4224/9112 samples
# Looked at 4256/9112 samples
# Looked at 4288/9112 samples
# Looked at 4320/9112 samples
# Looked at 4352/9112 samples
# Looked at 4384/9112 samples
# Looked at 4416/9112 samples
# Looked at 4448/9112 samples
# Looked at 4480/9112 samples
# Looked at 4512/9112 samples
# Looked at 4544/9112 samples
# Looked at 4576/9112 samples
# Looked at 4608/9112 samples
# Looked at 4640/9112 samples
# Looked at 4672/9112 samples
# Looked at 4704/9112 samples
# Looked at 4736/9112 samples
# Looked at 4768/9112 samples
# Looked at 4800/9112 samples
# Looked at 4832/9112 samples
# Looked at 4864/9112 samples
# Looked at 4896/9112 samples
# Looked at 4928/9112 samples
# Looked at 4960/9112 samples
# Looked at 4992/9112 samples
# Looked at 5024/9112 samples
# Looked at 5056/9112 samples
# Looked at 5088/9112 samples
# Looked at 5120/9112 samples
# Looked at 5152/9112 samples
# Looked at 5184/9112 samples
# Looked at 5216/9112 samples
# Looked at 5248/9112 samples
# Looked at 5280/9112 samples
# Looked at 5312/9112 samples
# Looked at 5344/9112 samples
# Looked at 5376/9112 samples
# Looked at 5408/9112 samples
# Looked at 5440/9112 samples
# Looked at 5472/9112 samples
# Looked at 5504/9112 samples
# Looked at 5536/9112 samples
# Looked at 5568/9112 samples
# Looked at 5600/9112 samples
# Looked at 5632/9112 samples
# Looked at 5664/9112 samples
# Looked at 5696/9112 samples
# Looked at 5728/9112 samples
# Looked at 5760/9112 samples
# Looked at 5792/9112 samples
# Looked at 5824/9112 samples
# Looked at 5856/9112 samples
# Looked at 5888/9112 samples
# Looked at 5920/9112 samples
# Looked at 5952/9112 samples
# Looked at 5984/9112 samples
# Looked at 6016/9112 samples
# Looked at 6048/9112 samples
# Looked at 6080/9112 samples
# Looked at 6112/9112 samples
# Looked at 6144/9112 samples
# Looked at 6176/9112 samples
# Looked at 6208/9112 samples
# Looked at 6240/9112 samples
# Looked at 6272/9112 samples
# Looked at 6304/9112 samples
# Looked at 6336/9112 samples
# Looked at 6368/9112 samples
# Looked at 6400/9112 samples
# Looked at 6432/9112 samples
# Looked at 6464/9112 samples
# Looked at 6496/9112 samples
# Looked at 6528/9112 samples
# Looked at 6560/9112 samples
# Looked at 6592/9112 samples
# Looked at 6624/9112 samples
# Looked at 6656/9112 samples
# Looked at 6688/9112 samples
# Looked at 6720/9112 samples
# Looked at 6752/9112 samples
# Looked at 6784/9112 samples
# Looked at 6816/9112 samples
# Looked at 6848/9112 samples
# Looked at 6880/9112 samples
# Looked at 6912/9112 samples
# Looked at 6944/9112 samples
# Looked at 6976/9112 samples
# Looked at 7008/9112 samples
# Looked at 7040/9112 samples
# Looked at 7072/9112 samples
# Looked at 7104/9112 samples
# Looked at 7136/9112 samples
# Looked at 7168/9112 samples
# Looked at 7200/9112 samples
# Looked at 7232/9112 samples
# Looked at 7264/9112 samples
# Looked at 7296/9112 samples
# Looked at 7328/9112 samples
# Looked at 7360/9112 samples
# Looked at 7392/9112 samples
# Looked at 7424/9112 samples
# Looked at 7456/9112 samples
# Looked at 7488/9112 samples
# Looked at 7520/9112 samples
# Looked at 7552/9112 samples
# Looked at 7584/9112 samples
# Looked at 7616/9112 samples
# Looked at 7648/9112 samples
# Looked at 7680/9112 samples
# Looked at 7712/9112 samples
# Looked at 7744/9112 samples
# Looked at 7776/9112 samples
# Looked at 7808/9112 samples
# Looked at 7840/9112 samples
# Looked at 7872/9112 samples
# Looked at 7904/9112 samples
# Looked at 7936/9112 samples
# Looked at 7968/9112 samples
# Looked at 8000/9112 samples
# Looked at 8032/9112 samples
# Looked at 8064/9112 samples
# Looked at 8096/9112 samples
# Looked at 8128/9112 samples
# Looked at 8160/9112 samples
# Looked at 8192/9112 samples
# Looked at 8224/9112 samples
# Looked at 8256/9112 samples
# Looked at 8288/9112 samples
# Looked at 8320/9112 samples
# Looked at 8352/9112 samples
# Looked at 8384/9112 samples
# Looked at 8416/9112 samples
# Looked at 8448/9112 samples
# Looked at 8480/9112 samples
# Looked at 8512/9112 samples
# Looked at 8544/9112 samples
# Looked at 8576/9112 samples
# Looked at 8608/9112 samples
# Looked at 8640/9112 samples
# Looked at 8672/9112 samples
# Looked at 8704/9112 samples
# Looked at 8736/9112 samples
# Looked at 8768/9112 samples
# Looked at 8800/9112 samples
# Looked at 8832/9112 samples
# Looked at 8864/9112 samples
# Looked at 8896/9112 samples
# Looked at 8928/9112 samples
# Looked at 8960/9112 samples
# Looked at 8992/9112 samples
# Looked at 9024/9112 samples
# Looked at 9056/9112 samples
# Looked at 6816/9112 samples
#
# Train loss: 0.11070, Train acc: 96.33% | Test loss: 1.21927, Test acc: 70.00%
#
# Train time on mps:0: 332.091 seconds
