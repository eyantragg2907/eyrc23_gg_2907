# %%
import tensorflow as tf

# %%
model = tf.keras.models.load_model("models/model_75x75.h5")
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# /Users/pranjalrastogi/eyantra/eyrc23_gg_2907/Task_2/Task_2B/model-saver.ipynb Cell 2 line 1
# ----> <a href='vscode-notebook-cell:/Users/pranjalrastogi/eyantra/eyrc23_gg_2907/Task_2/Task_2B/model-saver.ipynb#W1sZmlsZQ%3D%3D?line=0'>1</a> model = tf.keras.models.load_model("models/model_75x75.h5")
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/GG_2907/lib/python3.9/site-packages/keras/src/saving/saving_api.py:262, in load_model(filepath, custom_objects, compile, safe_mode, **kwargs)
#     254     return saving_lib.load_model(
#     255         filepath,
#     256         custom_objects=custom_objects,
#     257         compile=compile,
#     258         safe_mode=safe_mode,
#     259     )
#     261 # Legacy case.
# --> 262 return legacy_sm_saving_lib.load_model(
# ...

# %%
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ...
#  input_2 (InputLayer)        [(None, 75, 75, 3)]          0         []
#
#  conv2d_94 (Conv2D)          (None, 37, 37, 32)           864       ['input_2[0][0]']
#
#  batch_normalization_94 (Ba  (None, 37, 37, 32)           96        ['conv2d_94[0][0]']
#  tchNormalization)
#
#  activation_94 (Activation)  (None, 37, 37, 32)           0         ['batch_normalization_94[0][0]
#                                                                     ']
#
#  conv2d_95 (Conv2D)          (None, 35, 35, 32)           9216      ['activation_94[0][0]']
#
#  batch_normalization_95 (Ba  (None, 35, 35, 32)           96        ['conv2d_95[0][0]']
#  tchNormalization)
#
#  activation_95 (Activation)  (None, 35, 35, 32)           0         ['batch_normalization_95[0][0]
# ...
